# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'E:\Rustin Project\Bikes-new.csv')
df.head()
# Out:
#     S_T Gender_M Gender_F Helmet_Y Helmet_N Passenger_Y Passenger_N  \
# 0  7:00        X      NaN      NaN        X         NaN           X
# 1  7:00        X      NaN      NaN        X         NaN           X
# 2  7:00        X      NaN      NaN        X         NaN           X
# 3  7:00        X      NaN      NaN        X         NaN           X
# 4  7:00        X      NaN      NaN        X         NaN           X
#
#   Sidewalk_Y Sidewalk_N
# 0        NaN          X
# 1        NaN          X
# 2        NaN          X
# 3        NaN          X
# 4        NaN          X

# %%
df = df.fillna(0)
df.head()
# Out:
#     S_T Gender_M Gender_F Helmet_Y Helmet_N Passenger_Y Passenger_N  \
# 0  7:00        X        0        0        X           0           X
# 1  7:00        X        0        0        X           0           X
# 2  7:00        X        0        0        X           0           X
# 3  7:00        X        0        0        X           0           X
# 4  7:00        X        0        0        X           0           X
#
#   Sidewalk_Y Sidewalk_N
# 0          0          X
# 1          0          X
# 2          0          X
# 3          0          X
# 4          0          X

# %%
date = '2010-09-24 '   
df.insert(loc=1, column='Date', value=date)
df.head()
# Out:
#     S_T         Date Gender_M Gender_F Helmet_Y Helmet_N Passenger_Y  \
# 0  7:00  2010-09-24         X        0        0        X           0
# 1  7:00  2010-09-24         X        0        0        X           0
# 2  7:00  2010-09-24         X        0        0        X           0
# 3  7:00  2010-09-24         X        0        0        X           0
# 4  7:00  2010-09-24         X        0        0        X           0
#
#   Passenger_N Sidewalk_Y Sidewalk_N
# 0           X          0          X
# 1           X          0          X
# 2           X          0          X
# 3           X          0          X
# 4           X          0          X

# %%
new_val = df["Date"].map(str) + df["S_T"]
df.insert(loc=0, column='Date_Time', value=new_val)
df.head()
# Out:
#          Date_Time   S_T         Date Gender_M Gender_F Helmet_Y Helmet_N  \
# 0  2010-09-24 7:00  7:00  2010-09-24         X        0        0        X
# 1  2010-09-24 7:00  7:00  2010-09-24         X        0        0        X
# 2  2010-09-24 7:00  7:00  2010-09-24         X        0        0        X
# 3  2010-09-24 7:00  7:00  2010-09-24         X        0        0        X
# 4  2010-09-24 7:00  7:00  2010-09-24         X        0        0        X
#
#   Passenger_Y Passenger_N Sidewalk_Y Sidewalk_N
# 0           0           X          0          X
# 1           0           X          0          X
# 2           0           X          0          X
# 3           0           X          0          X
# 4           0           X          0          X

# %%
del df['S_T']

# %%
df
# Out:
#              Date_Time         Date Gender_M Gender_F Helmet_Y Helmet_N  \
# 0      2010-09-24 7:00  2010-09-24         X        0        0        X
# 1      2010-09-24 7:00  2010-09-24         X        0        0        X
# 2      2010-09-24 7:00  2010-09-24         X        0        0        X
# 3      2010-09-24 7:00  2010-09-24         X        0        0        X
# 4      2010-09-24 7:00  2010-09-24         X        0        0        X
# 5      2010-09-24 7:15  2010-09-24         X        0        X        0
# 6      2010-09-24 7:15  2010-09-24         0        X        X        0
# 7      2010-09-24 7:15  2010-09-24         X        0        X        0
# 8      2010-09-24 7:15  2010-09-24         0        X        X        0
# 9      2010-09-24 7:15  2010-09-24         X        0        X        0
# 10     2010-09-24 7:15  2010-09-24         X        0        X        0
# 11     2010-09-24 7:15  2010-09-24         X        0        X        0
# ...

# %%
del df['Date']

# %%
df
# Out:
#              Date_Time Gender_M Gender_F Helmet_Y Helmet_N Passenger_Y  \
# 0      2010-09-24 7:00        X        0        0        X           0
# 1      2010-09-24 7:00        X        0        0        X           0
# 2      2010-09-24 7:00        X        0        0        X           0
# 3      2010-09-24 7:00        X        0        0        X           0
# 4      2010-09-24 7:00        X        0        0        X           0
# 5      2010-09-24 7:15        X        0        X        0           0
# 6      2010-09-24 7:15        0        X        X        0           0
# 7      2010-09-24 7:15        X        0        X        0           0
# 8      2010-09-24 7:15        0        X        X        0           0
# 9      2010-09-24 7:15        X        0        X        0           0
# 10     2010-09-24 7:15        X        0        X        0           0
# 11     2010-09-24 7:15        X        0        X        0           0
# ...

# %%
new_df = df.Gender_M.replace(['X',0],['Male','Female'])
new_df
# Out:
# 0         Male
# 1         Male
# 2         Male
# 3         Male
# 4         Male
# 5         Male
# 6       Female
# 7         Male
# 8       Female
# 9         Male
# 10        Male
# 11        Male
# 12      Female
# 13        Male
# 14        Male
# 15        Male
# 16      Female
# 17        Male
# 18      Female
# 19        Male
# 20      Female
# 21        Male
# 22        Male
# 23      Female
# 24      Female
# 25        Male
# 26        Male
# 27      Female
# 28        Male
# 29        Male
#          ...
# 1928      Male
# 1929    Female
# 1930    Female
# 1931      Male
# 1932    Female
# 1933    Female
# 1934    Female
# 1935      Male
# 1936      Male
# 1937    Female
# 1938      Male
# 1939    Female
# 1940      Male
# 1941    Female
# 1942    Female
# 1943    Female
# 1944      Male
# 1945    Female
# 1946      Male
# 1947      Male
# 1948      Male
# 1949      Male
# 1950      Male
# 1951    Female
# 1952    Female
# 1953      Male
# 1954    Female
# ...

# %%
new_val = new_df
df.insert(loc=1, column='Gender', value=new_val)
df.head()
# Out:
#          Date_Time Gender Gender_M Gender_F Helmet_Y Helmet_N Passenger_Y  \
# 0  2010-09-24 7:00   Male        X        0        0        X           0
# 1  2010-09-24 7:00   Male        X        0        0        X           0
# 2  2010-09-24 7:00   Male        X        0        0        X           0
# 3  2010-09-24 7:00   Male        X        0        0        X           0
# 4  2010-09-24 7:00   Male        X        0        0        X           0
#
#   Passenger_N Sidewalk_Y Sidewalk_N
# 0           X          0          X
# 1           X          0          X
# 2           X          0          X
# 3           X          0          X
# 4           X          0          X

# %%
del df['Gender_M']

# %%
del df['Gender_F']

# %%
df.head()
# Out:
#          Date_Time Gender Helmet_Y Helmet_N Passenger_Y Passenger_N  \
# 0  2010-09-24 7:00   Male        0        X           0           X
# 1  2010-09-24 7:00   Male        0        X           0           X
# 2  2010-09-24 7:00   Male        0        X           0           X
# 3  2010-09-24 7:00   Male        0        X           0           X
# 4  2010-09-24 7:00   Male        0        X           0           X
#
#   Sidewalk_Y Sidewalk_N
# 0          0          X
# 1          0          X
# 2          0          X
# 3          0          X
# 4          0          X

# %%
new_df = df.Helmet_Y.replace(['X',0],['Yes','No'])
new_val = new_df
df.insert(loc=2, column='Had_Helmet', value=new_val)
df.head()
# Out:
#          Date_Time Gender Had_Helmet Helmet_Y Helmet_N Passenger_Y  \
# 0  2010-09-24 7:00   Male         No        0        X           0
# 1  2010-09-24 7:00   Male         No        0        X           0
# 2  2010-09-24 7:00   Male         No        0        X           0
# 3  2010-09-24 7:00   Male         No        0        X           0
# 4  2010-09-24 7:00   Male         No        0        X           0
#
#   Passenger_N Sidewalk_Y Sidewalk_N
# 0           X          0          X
# 1           X          0          X
# 2           X          0          X
# 3           X          0          X
# 4           X          0          X

# %%
del df['Helmet_Y']
del df['Helmet_N']

# %%
df.head()
# Out:
#          Date_Time Gender Had_Helmet Passenger_Y Passenger_N Sidewalk_Y  \
# 0  2010-09-24 7:00   Male         No           0           X          0
# 1  2010-09-24 7:00   Male         No           0           X          0
# 2  2010-09-24 7:00   Male         No           0           X          0
# 3  2010-09-24 7:00   Male         No           0           X          0
# 4  2010-09-24 7:00   Male         No           0           X          0
#
#   Sidewalk_N
# 0          X
# 1          X
# 2          X
# 3          X
# 4          X

# %%
new_df = df.Passenger_Y.replace(['X',0],['Yes','No'])
new_val = new_df
df.insert(loc=3, column='Had_Passenger', value=new_val)
df.head()
# Out:
#          Date_Time Gender Had_Helmet Had_Passenger Passenger_Y Passenger_N  \
# 0  2010-09-24 7:00   Male         No            No           0           X
# 1  2010-09-24 7:00   Male         No            No           0           X
# 2  2010-09-24 7:00   Male         No            No           0           X
# 3  2010-09-24 7:00   Male         No            No           0           X
# 4  2010-09-24 7:00   Male         No            No           0           X
#
#   Sidewalk_Y Sidewalk_N
# 0          0          X
# 1          0          X
# 2          0          X
# 3          0          X
# 4          0          X

# %%
del df['Passenger_Y']
del df['Passenger_N']

# %%
df.head()
# Out:
#          Date_Time Gender Had_Helmet Had_Passenger Sidewalk_Y Sidewalk_N
# 0  2010-09-24 7:00   Male         No            No          0          X
# 1  2010-09-24 7:00   Male         No            No          0          X
# 2  2010-09-24 7:00   Male         No            No          0          X
# 3  2010-09-24 7:00   Male         No            No          0          X
# 4  2010-09-24 7:00   Male         No            No          0          X

# %%
new_df = df.Sidewalk_Y.replace(['X',0],['Yes','No'])
new_val = new_df
df.insert(loc=4, column='On_Sidewalk', value=new_val)
df.head()
# Out:
#          Date_Time Gender Had_Helmet Had_Passenger On_Sidewalk Sidewalk_Y  \
# 0  2010-09-24 7:00   Male         No            No          No          0
# 1  2010-09-24 7:00   Male         No            No          No          0
# 2  2010-09-24 7:00   Male         No            No          No          0
# 3  2010-09-24 7:00   Male         No            No          No          0
# 4  2010-09-24 7:00   Male         No            No          No          0
#
#   Sidewalk_N
# 0          X
# 1          X
# 2          X
# 3          X
# 4          X

# %%
del df['Sidewalk_Y']
del df['Sidewalk_N']

# %%
df.head()
# Out:
#          Date_Time Gender Had_Helmet Had_Passenger On_Sidewalk
# 0  2010-09-24 7:00   Male         No            No          No
# 1  2010-09-24 7:00   Male         No            No          No
# 2  2010-09-24 7:00   Male         No            No          No
# 3  2010-09-24 7:00   Male         No            No          No
# 4  2010-09-24 7:00   Male         No            No          No

# %%
df.to_csv('E:\Rustin Project\Final_Bikes.csv')
